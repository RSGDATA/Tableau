# %%
import pandas as pd

import datetime as dt

import numpy as np

# %%
may_df = pd.read_csv("citibike_may_21.csv")

may_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                   ended_at             start_station_name start_station_id  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
june_df = pd.read_csv("citibike_june_21.csv")

june_df
# Out:
#                 ride_id rideable_type           started_at  \
# 0      7830EBE775F2EE25  classic_bike  2021-06-21 07:38:42
# 1      629A3BFD50BF8392   docked_bike  2021-06-12 10:25:01
# 2      CF02EC434989A99D   docked_bike  2021-06-07 14:52:05
# 3      E1BB8FED29AA5BA1   docked_bike  2021-06-07 08:29:19
# 4      787C59EE76D96BCA   docked_bike  2021-06-18 14:16:27
# ...                 ...           ...                  ...
# 71437  837E135024442757   docked_bike  2021-06-06 22:07:08
# 71438  14F127B834A8ED72   docked_bike  2021-06-20 20:53:48
# 71439  A9FE39A9E76C2192   docked_bike  2021-06-01 21:27:29
# 71440  E0FCE3CE0160B4E0   docked_bike  2021-06-11 15:22:44
# 71441  B342E07B460305A1   docked_bike  2021-06-06 23:22:42
#
#                   ended_at     start_station_name start_station_id  \
# 0      2021-06-21 10:49:25            Dixon Mills            JC076
# 1      2021-06-12 10:35:11            Dixon Mills            JC076
# ...

# %%
july_df = pd.read_csv("citibike_july_21.csv")

july_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      C9446233AFAB8896   classic_bike  2021-07-15 19:27:25
# 1      0C3D69370BE39992  electric_bike  2021-07-22 06:41:54
# 2      3B0390B706281176   classic_bike  2021-07-19 06:36:13
# 3      9AFBC07247ABE507   classic_bike  2021-07-08 06:33:45
# 4      ADB073F7FFC372D3   classic_bike  2021-07-21 07:33:49
# ...                 ...            ...                  ...
# 82573  3EC1B265DBD89895   classic_bike  2021-07-31 17:01:57
# 82574  6D6303B3D638B24C  electric_bike  2021-07-21 09:12:09
# 82575  CC8F22DE9DA05F09  electric_bike  2021-07-19 18:51:33
# 82576  A846B2B1CECD7F09   classic_bike  2021-07-19 20:45:41
# 82577  37858A6DFC7A9A88   classic_bike  2021-07-10 16:06:35
#
#                   ended_at                            start_station_name  \
# 0      2021-07-15 19:27:35                                Journal Square
# 1      2021-07-22 06:42:03                                Journal Square
# ...

# %%
month_list = [may_df, june_df, july_df]  # List of your dataframes
all_months_df = pd.concat(month_list)
g_bike = all_months_df.groupby(["start_station_id","end_station_id"]).count()

bike_new_index = g_bike.reset_index()

# %%
bike_new_index

all_months_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      74A4206E7487CBC9    docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE    docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59    docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD    docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA    docked_bike  2021-05-14 09:48:34
# ...                 ...            ...                  ...
# 82573  3EC1B265DBD89895   classic_bike  2021-07-31 17:01:57
# 82574  6D6303B3D638B24C  electric_bike  2021-07-21 09:12:09
# 82575  CC8F22DE9DA05F09  electric_bike  2021-07-19 18:51:33
# 82576  A846B2B1CECD7F09   classic_bike  2021-07-19 20:45:41
# 82577  37858A6DFC7A9A88   classic_bike  2021-07-10 16:06:35
#
#                   ended_at                            start_station_name  \
# 0      2021-05-23 18:38:21                 9 St HBLR - Jackson St & 8 St
# 1      2021-05-31 16:55:28                 9 St HBLR - Jackson St & 8 St
# ...

# %%
null_df = all_months_df.isnull()

clean_all_months = all_months_df.dropna()

new_df2 = clean_all_months.groupby("start_station_name").min()

# casual_df = clean_all_months.loc[clean_all_months["member_casual"] == "casual"]

# member_df = clean_all_months.loc[clean_all_months["member_casual"] == "member"]

# casual_df.set_index("start_station_name")

new_df2
# Out:
#                                             ride_id rideable_type  \
# start_station_name
# 11 St & Washington St              0001EE0246F27103  classic_bike
# 14 St Ferry - 14 St & Shipyard Ln  002C3CF3E100762C  classic_bike
# 2 St HBLR - 2 St & Marshall St     00A5676ADDF57346  classic_bike
# 4 St & Grand St                    00516C6D0798213F  classic_bike
# 5 Corners Library                  00626095043DCF3D  classic_bike
# ...                                             ...           ...
# Union St                           002FE86200809B4C  classic_bike
# Van Vorst Park                     0012E9D014749D35  classic_bike
# Warren St                          004826C1DE7A222B  classic_bike
# Washington St                      000B52A651859FEA  classic_bike
# Willow Ave & 12 St                 0029AEF7A1A61DDA  classic_bike
#
#                                             started_at             ended_at  \
# start_station_name
# ...

# %%
citi_bike_df = clean_all_months.to_csv("all_months_citibike.csv")

citi_bike_df

# %%
null_df = all_months_df.isnull()

clean_all_months = all_months_df.dropna()

clean_all_months(pd.to_datetime()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_1048/2244504717.py in <module>
#       3 clean_all_months = all_months_df.dropna()
#       4
# ----> 5 clean_all_months(pd.to_datetime())
#
# TypeError: to_datetime() missing 1 required positional argument: 'arg'

# %%
april_19 = pd.read_csv("citibike_april_19.csv")

# %%
may_19 = pd.read_csv("citibike_may_19.csv")

# %%
june_19 = pd.read_csv("citibike_june_19.csv")

# %%
month_list = [april_19, may_19, june_19]

all_month_19 = pd.concat(month_list)

all_month_19

# %%
all_month_19.loc[all_month_19['gender'] != 0]

all_month_19

all_month_no_0 = all_month_19.loc[(all_month_19 != 0).all(axis=1), :]

all_month_no_0

# %%
all_months_19 = all_month_no_0.to_csv("citibike_3_months.csv")
